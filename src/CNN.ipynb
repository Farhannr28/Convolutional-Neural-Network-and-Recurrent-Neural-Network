# %% [markdown]
# # CNN Model
#
# ### Made By Team 9:
#
# |   NIM    |            Name            |
# | :------: | :------------------------: |
# | 13522037 |    Farhan Nafis Rayhan     |
# | 13522071 |   Bagas Sambega Rosyada    |
# | 13522091 | Raden Francisco Trianto B. |

# %% [markdown]
# ### Import Library

# %%
import sys
from pathlib import Path

project_root = Path().resolve().parent  
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.pipeline.cnn_pipeline import CNNSuite
from src.utils.plot_utils import plot_multi_loss

# %% [markdown]
# ## Hyperparameter: Number of Convolutional Layers

# %% [markdown]
# ### 1. Number of Conv Layers = 1

# %%
cnn_convLayer_1 = CNNSuite(save_dir="saved_models", model_name="cnn_convLayers_1.keras")
cnn_convLayer_1.history_path = cnn_convLayer_1.save_dir / "cnn_convLayers_1_history.json"
cnn_convLayer_1.load_data()

if cnn_convLayer_1.model_path.exists() and cnn_convLayer_1.history_path.exists():
    print("[INFO] Model and history already exist. Skipping training and loading history...")
    cnn_convLayer_1.load_history()
else:
    cnn_convLayer_1.train(epochs=10, batch_size=64, conv_layers=1)

keras_cnn_convLayer_1 = cnn_convLayer_1.evaluate_keras()
scratch_cnn_convLayer_1 = cnn_convLayer_1.evaluate_scratch()
cnn_convLayer_1.plot_history()
print(f"[RESULT] Conv Layers = 1 | Keras F1 = {keras_cnn_convLayer_1:.6f} | Scratch F1 = {scratch_cnn_convLayer_1:.6f}\n")
# Out:
# [INIT] Initializing CNNSuite with model path 'saved_models/cnn_convLayers_1.keras'
# [START] Loading dataset...
# [INFO] Downloading CIFAR-10 dataset...
# [INFO] Dataset downloaded successfully.
# [INFO] Normalizing image data...
# [INFO] Splitting training data: 50000 samples into 40000 train and 10000 validation samples.
# [INFO] Data loading and splitting complete.
# [DONE] Dataset loaded:
#   - train: (40000, 32, 32, 3), (40000,)
#   - val: (10000, 32, 32, 3), (10000,)
#   - test: (10000, 32, 32, 3), (10000,)
# [INFO] Model and history already exist. Skipping training and loading history...
# [INFO] Loading training history from saved_models\cnn_convLayers_1_history.json...
# [INFO] Training history loaded.
# [START] Evaluating Keras model on test set...
# [DONE] Macro F1-score (Keras): 0.6435
# [START] Evaluating scratch CNN on test set...
# [DONE] Macro F1-score (scratch): 0.6435
# [START] Plotting training loss and accuracy history...
# [INFO] Using cached training history.
# [DONE] Plot displayed.
# [RESULT] Conv Layers = 1 | Keras F1 = 0.643511 | Scratch F1 = 0.643511

# %% [markdown]
# ### 2. Number of Conv Layers = 2

# %%
cnn_convLayer_2 = CNNSuite(save_dir="saved_models", model_name="cnn_convLayers_2.keras")
cnn_convLayer_2.history_path = cnn_convLayer_2.save_dir / "cnn_convLayers_2_history.json"
cnn_convLayer_2.load_data()
if cnn_convLayer_2.model_path.exists() and cnn_convLayer_2.history_path.exists():
    print("[INFO] Model and history already exist. Skipping training and loading history...")
    cnn_convLayer_2.load_history()
else:
    cnn_convLayer_2.train(epochs=10, batch_size=64, conv_layers=2)
keras_cnn_convLayer_2 = cnn_convLayer_2.evaluate_keras()
scratch_cnn_convLayer_2 = cnn_convLayer_2.evaluate_scratch()
cnn_convLayer_2.plot_history()
print(f"[RESULT] Conv Layers = 2 | Keras F1 = {keras_cnn_convLayer_2:.6f} | Scratch F1 = {scratch_cnn_convLayer_2:.6f}\n")
# Out:
# [INIT] Initializing CNNSuite with model path 'saved_models/cnn_convLayers_2.keras'
# [START] Loading dataset...
# [INFO] Downloading CIFAR-10 dataset...
# [INFO] Dataset downloaded successfully.
# [INFO] Normalizing image data...
# [INFO] Splitting training data: 50000 samples into 40000 train and 10000 validation samples.
# [INFO] Data loading and splitting complete.
# [DONE] Dataset loaded:
#   - train: (40000, 32, 32, 3), (40000,)
#   - val: (10000, 32, 32, 3), (10000,)
#   - test: (10000, 32, 32, 3), (10000,)
# [START] Training with 32 filters, 10 epochs...
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 16s 23ms/step - accuracy: 0.3564 - loss: 1.7677 - val_accuracy: 0.5420 - val_loss: 1.2819
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 12s 18ms/step - accuracy: 0.5712 - loss: 1.2206 - val_accuracy: 0.6087 - val_loss: 1.1102
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.6293 - loss: 1.0557 - val_accuracy: 0.6448 - val_loss: 1.0110
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.6686 - loss: 0.9472 - val_accuracy: 0.6539 - val_loss: 0.9823
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.6937 - loss: 0.8730 - val_accuracy: 0.6617 - val_loss: 0.9570
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.7201 - loss: 0.8070 - val_accuracy: 0.6717 - val_loss: 0.9354
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.7421 - loss: 0.7414 - val_accuracy: 0.6728 - val_loss: 0.9364
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.7556 - loss: 0.6956 - val_accuracy: 0.6856 - val_loss: 0.9301
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 24ms/step - accuracy: 0.7783 - loss: 0.6424 - val_accuracy: 0.6797 - val_loss: 0.9341
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.7919 - loss: 0.5978 - val_accuracy: 0.6922 - val_loss: 0.9261
# Model saved to d:\Repositories\Convolutional-Neural-Network-and-Recurrent-Neural-Network\src\saved_models\cnn_convLayers_2.keras
# Training history saved to d:\Repositories\Convolutional-Neural-Network-and-Recurrent-Neural-Network\src\saved_models\cnn_convLayers_2_history.json
# Test Macro F1 Score: 0.6868415477926352
# [DONE] Training finished - macro F1 on test (Keras): 0.6868
# [START] Evaluating Keras model on test set...
# [DONE] Macro F1-score (Keras): 0.6868
# [START] Evaluating scratch CNN on test set...
# [DONE] Macro F1-score (scratch): 0.6868
# [START] Plotting training loss and accuracy history...
# [INFO] Using cached training history.
# [DONE] Plot displayed.
# [RESULT] Conv Layers = 2 | Keras F1 = 0.686842 | Scratch F1 = 0.686842

# %% [markdown]
# ### 3. Number of Conv Layers = 3

# %%
cnn_convLayer_3 = CNNSuite(save_dir="saved_models", model_name="cnn_convLayers_3.keras")
cnn_convLayer_3.history_path = cnn_convLayer_3.save_dir / "cnn_convLayers_3_history.json"
cnn_convLayer_3.load_data()
if cnn_convLayer_3.model_path.exists() and cnn_convLayer_3.history_path.exists():
    print("[INFO] Model and history already exist. Skipping training and loading history...")
    cnn_convLayer_3.load_history()
else:
    cnn_convLayer_3.train(epochs=10, batch_size=64, conv_layers=3)
keras_cnn_convLayer_3 = cnn_convLayer_3.evaluate_keras()
scratch_cnn_convLayer_3 = cnn_convLayer_3.evaluate_scratch()
cnn_convLayer_3.plot_history()
print(f"[RESULT] Conv Layers = 3 | Keras F1 = {keras_cnn_convLayer_3:.6f} | Scratch F1 = {scratch_cnn_convLayer_3:.6f}\n")
# Out:
# [INIT] Initializing CNNSuite with model path 'saved_models/cnn_convLayers_3.keras'
# [START] Loading dataset...
# [INFO] Downloading CIFAR-10 dataset...
# [INFO] Dataset downloaded successfully.
# [INFO] Normalizing image data...
# [INFO] Splitting training data: 50000 samples into 40000 train and 10000 validation samples.
# [INFO] Data loading and splitting complete.
# [DONE] Dataset loaded:
#   - train: (40000, 32, 32, 3), (40000,)
#   - val: (10000, 32, 32, 3), (10000,)
#   - test: (10000, 32, 32, 3), (10000,)
# [START] Training with 32 filters, 10 epochs...
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.3365 - loss: 1.8163 - val_accuracy: 0.4914 - val_loss: 1.4061
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 23ms/step - accuracy: 0.5481 - loss: 1.2733 - val_accuracy: 0.5720 - val_loss: 1.1846
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.6189 - loss: 1.0876 - val_accuracy: 0.6398 - val_loss: 1.0306
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.6553 - loss: 0.9814 - val_accuracy: 0.6613 - val_loss: 0.9641
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.6829 - loss: 0.9054 - val_accuracy: 0.6724 - val_loss: 0.9425
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.7075 - loss: 0.8379 - val_accuracy: 0.6995 - val_loss: 0.8682
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.7316 - loss: 0.7736 - val_accuracy: 0.7028 - val_loss: 0.8513
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 24ms/step - accuracy: 0.7450 - loss: 0.7370 - val_accuracy: 0.6933 - val_loss: 0.8893
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 23ms/step - accuracy: 0.7583 - loss: 0.6929 - val_accuracy: 0.7016 - val_loss: 0.8684
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.7719 - loss: 0.6493 - val_accuracy: 0.7011 - val_loss: 0.8788
# Model saved to d:\Repositories\Convolutional-Neural-Network-and-Recurrent-Neural-Network\src\saved_models\cnn_convLayers_3.keras
# Training history saved to d:\Repositories\Convolutional-Neural-Network-and-Recurrent-Neural-Network\src\saved_models\cnn_convLayers_3_history.json
# Test Macro F1 Score: 0.7023930583932579
# [DONE] Training finished - macro F1 on test (Keras): 0.7024
# [START] Evaluating Keras model on test set...
# [DONE] Macro F1-score (Keras): 0.7024
# [START] Evaluating scratch CNN on test set...
# [DONE] Macro F1-score (scratch): 0.7024
# [START] Plotting training loss and accuracy history...
# [INFO] Using cached training history.
# [DONE] Plot displayed.
# [RESULT] Conv Layers = 3 | Keras F1 = 0.702393 | Scratch F1 = 0.702393

# %%
histories_1 = {
    "1 layer": cnn_convLayer_1.load_history(),
    "2 layers": cnn_convLayer_2.load_history(),
    "3 layers": cnn_convLayer_3.load_history(),
}

plot_multi_loss(histories_1)
# Out:
# [INFO] Using cached training history.
# [INFO] Using cached training history.
# [INFO] Using cached training history.

# %% [markdown]
# ## Hyperparameter: Number of Filter

# %% [markdown]
# ### 1. Filters = [16, 32]

# %%
cnn_filters_16_32 = CNNSuite(save_dir="saved_models", model_name="cnn_filters_16_32.keras")
cnn_filters_16_32.history_path = cnn_filters_16_32.save_dir / "cnn_filters_16_32_history.json"
cnn_filters_16_32.load_data()
if cnn_filters_16_32.model_path.exists() and cnn_filters_16_32.history_path.exists():
    print("[INFO] Model and history already exist. Skipping training and loading history...")
    cnn_filters_16_32.load_history()
else:
    cnn_filters_16_32.train(
        epochs=10,
        batch_size=64,
        conv_layers=2,
        filters=[16, 32]        
    )
keras_cnn_filters_16_32   = cnn_filters_16_32.evaluate_keras()
scratch_cnn_filters_16_32 = cnn_filters_16_32.evaluate_scratch()
cnn_filters_16_32.plot_history()  
print(f"[RESULT] Filters [16, 32] | Keras F1: {keras_cnn_filters_16_32:.6f} | Scratch F1: {scratch_cnn_filters_16_32:.6f}")
# Out:
# [INIT] Initializing CNNSuite with model path 'saved_models/cnn_filters_16_32.keras'
# [START] Loading dataset...
# [INFO] Downloading CIFAR-10 dataset...
# [INFO] Dataset downloaded successfully.
# [INFO] Normalizing image data...
# [INFO] Splitting training data: 50000 samples into 40000 train and 10000 validation samples.
# [INFO] Data loading and splitting complete.
# [DONE] Dataset loaded:
#   - train: (40000, 32, 32, 3), (40000,)
#   - val: (10000, 32, 32, 3), (10000,)
#   - test: (10000, 32, 32, 3), (10000,)
# [START] Training with [16, 32] filters, 10 epochs...
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 16ms/step - accuracy: 0.3528 - loss: 1.7895 - val_accuracy: 0.5154 - val_loss: 1.3380
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.5633 - loss: 1.2425 - val_accuracy: 0.5937 - val_loss: 1.1340
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.6281 - loss: 1.0635 - val_accuracy: 0.6347 - val_loss: 1.0403
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.6634 - loss: 0.9636 - val_accuracy: 0.6511 - val_loss: 1.0002
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.6910 - loss: 0.8980 - val_accuracy: 0.6652 - val_loss: 0.9633
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.7075 - loss: 0.8411 - val_accuracy: 0.6747 - val_loss: 0.9443
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.7280 - loss: 0.7835 - val_accuracy: 0.6755 - val_loss: 0.9335
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.7499 - loss: 0.7166 - val_accuracy: 0.6797 - val_loss: 0.9302
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.7635 - loss: 0.6788 - val_accuracy: 0.6702 - val_loss: 0.9670
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.7796 - loss: 0.6362 - val_accuracy: 0.6614 - val_loss: 1.0246
# Model saved to d:\Repositories\Convolutional-Neural-Network-and-Recurrent-Neural-Network\src\saved_models\cnn_filters_16_32.keras
# Training history saved to d:\Repositories\Convolutional-Neural-Network-and-Recurrent-Neural-Network\src\saved_models\cnn_filters_16_32_history.json
# Test Macro F1 Score: 0.6626044870248814
# [DONE] Training finished - macro F1 on test (Keras): 0.6626
# [START] Evaluating Keras model on test set...
# [DONE] Macro F1-score (Keras): 0.6626
# [START] Evaluating scratch CNN on test set...
# [DONE] Macro F1-score (scratch): 0.6626
# [START] Plotting training loss and accuracy history...
# [INFO] Using cached training history.
# [DONE] Plot displayed.
# [RESULT] Filters [16, 32] | Keras F1: 0.662604 | Scratch F1: 0.662604

# %% [markdown]
# ### 2. Filters = [32, 64]

# %%
cnn_filters_32_64 = CNNSuite(save_dir="saved_models", model_name="cnn_filters_32_64.keras")
cnn_filters_32_64.history_path = cnn_filters_32_64.save_dir / "cnn_filters_32_64_history.json"
cnn_filters_32_64.load_data()
if cnn_filters_32_64.model_path.exists() and cnn_filters_32_64.history_path.exists():
    print("[INFO] Model and history already exist. Skipping training and loading history...")
    cnn_filters_32_64.load_history()
else:
    cnn_filters_32_64.train(
        epochs=10,
        batch_size=64,
        conv_layers=2,
        filters=[32, 64]          
    )

keras_cnn_filters_32_64   = cnn_filters_32_64.evaluate_keras()
scratch_cnn_filters_32_64 = cnn_filters_32_64.evaluate_scratch()
cnn_filters_32_64.plot_history()  
print(f"[RESULT] Filters [32, 64] | Keras F1: {keras_cnn_filters_32_64:.6f} | Scratch F1: {scratch_cnn_filters_32_64:.6f}")
# Out:
# [INIT] Initializing CNNSuite with model path 'saved_models/cnn_filters_32_64.keras'
# [START] Loading dataset...
# [INFO] Downloading CIFAR-10 dataset...
# [INFO] Dataset downloaded successfully.
# [INFO] Normalizing image data...
# [INFO] Splitting training data: 50000 samples into 40000 train and 10000 validation samples.
# [INFO] Data loading and splitting complete.
# [DONE] Dataset loaded:
#   - train: (40000, 32, 32, 3), (40000,)
#   - val: (10000, 32, 32, 3), (10000,)
#   - test: (10000, 32, 32, 3), (10000,)
# [START] Training with [32, 64] filters, 10 epochs...
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 33ms/step - accuracy: 0.3670 - loss: 1.7367 - val_accuracy: 0.5631 - val_loss: 1.2324
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.6000 - loss: 1.1390 - val_accuracy: 0.6338 - val_loss: 1.0367
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.6654 - loss: 0.9571 - val_accuracy: 0.6669 - val_loss: 0.9527
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - accuracy: 0.7004 - loss: 0.8651 - val_accuracy: 0.6771 - val_loss: 0.9215
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - accuracy: 0.7254 - loss: 0.7919 - val_accuracy: 0.6904 - val_loss: 0.8899
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 24ms/step - accuracy: 0.7553 - loss: 0.7125 - val_accuracy: 0.7027 - val_loss: 0.8550
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 24ms/step - accuracy: 0.7794 - loss: 0.6382 - val_accuracy: 0.7056 - val_loss: 0.8578
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 24ms/step - accuracy: 0.7964 - loss: 0.5873 - val_accuracy: 0.7060 - val_loss: 0.8653
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - accuracy: 0.8170 - loss: 0.5244 - val_accuracy: 0.7032 - val_loss: 0.9058
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 24ms/step - accuracy: 0.8330 - loss: 0.4766 - val_accuracy: 0.7087 - val_loss: 0.9090
# Model saved to d:\Repositories\Convolutional-Neural-Network-and-Recurrent-Neural-Network\src\saved_models\cnn_filters_32_64.keras
# Training history saved to d:\Repositories\Convolutional-Neural-Network-and-Recurrent-Neural-Network\src\saved_models\cnn_filters_32_64_history.json
# Test Macro F1 Score: 0.7052822049329268
# [DONE] Training finished - macro F1 on test (Keras): 0.7053
# [START] Evaluating Keras model on test set...
# [DONE] Macro F1-score (Keras): 0.7053
# [START] Evaluating scratch CNN on test set...
# [DONE] Macro F1-score (scratch): 0.7053
# [START] Plotting training loss and accuracy history...
# [INFO] Using cached training history.
# [DONE] Plot displayed.
# [RESULT] Filters [32, 64] | Keras F1: 0.705282 | Scratch F1: 0.705282

# %% [markdown]
# ### 2. Filters = [64, 128]

# %%
cnn_filters_64_128 = CNNSuite(save_dir="saved_models", model_name="cnn_filters_64_128.keras")
cnn_filters_64_128.history_path = cnn_filters_64_128.save_dir / "cnn_filters_64_128_history.json"
cnn_filters_64_128.load_data()
if cnn_filters_64_128.model_path.exists() and cnn_filters_64_128.history_path.exists():
    print("[INFO] Model and history already exist. Skipping training and loading history...")
    cnn_filters_64_128.load_history()
else:
    cnn_filters_64_128.train(
        epochs=10,
        batch_size=64,
        conv_layers=2,
        filters=[64, 128]        
    )
keras_cnn_filters_64_128   = cnn_filters_64_128.evaluate_keras()
scratch_cnn_filters_64_128 = cnn_filters_64_128.evaluate_scratch()
cnn_filters_64_128.plot_history()  
print(f"[RESULT] Filters [64, 128] | Keras F1: {keras_cnn_filters_64_128:.6f} | Scratch F1: {scratch_cnn_filters_64_128:.6f}")
# Out:
# [INIT] Initializing CNNSuite with model path 'saved_models/cnn_filters_64_128.keras'
# [START] Loading dataset...
# [INFO] Downloading CIFAR-10 dataset...
# [INFO] Dataset downloaded successfully.
# [INFO] Normalizing image data...
# [INFO] Splitting training data: 50000 samples into 40000 train and 10000 validation samples.
# [INFO] Data loading and splitting complete.
# [DONE] Dataset loaded:
#   - train: (40000, 32, 32, 3), (40000,)
#   - val: (10000, 32, 32, 3), (10000,)
#   - test: (10000, 32, 32, 3), (10000,)
# [START] Training with [64, 128] filters, 10 epochs...
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 38s 59ms/step - accuracy: 0.3795 - loss: 1.7075 - val_accuracy: 0.5752 - val_loss: 1.1857
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 36s 58ms/step - accuracy: 0.6158 - loss: 1.1000 - val_accuracy: 0.6462 - val_loss: 1.0000
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 37s 59ms/step - accuracy: 0.6818 - loss: 0.9153 - val_accuracy: 0.6822 - val_loss: 0.8890
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 36s 58ms/step - accuracy: 0.7286 - loss: 0.7712 - val_accuracy: 0.6966 - val_loss: 0.8652
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 66ms/step - accuracy: 0.7643 - loss: 0.6792 - val_accuracy: 0.7105 - val_loss: 0.8387
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 37s 60ms/step - accuracy: 0.7957 - loss: 0.5821 - val_accuracy: 0.7134 - val_loss: 0.8464
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 37s 59ms/step - accuracy: 0.8253 - loss: 0.5092 - val_accuracy: 0.7138 - val_loss: 0.8666
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 36s 58ms/step - accuracy: 0.8592 - loss: 0.4097 - val_accuracy: 0.7233 - val_loss: 0.9236
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 59ms/step - accuracy: 0.8853 - loss: 0.3380 - val_accuracy: 0.6984 - val_loss: 1.0083
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 37s 59ms/step - accuracy: 0.9075 - loss: 0.2748 - val_accuracy: 0.7052 - val_loss: 1.0548
# Model saved to d:\Repositories\Convolutional-Neural-Network-and-Recurrent-Neural-Network\src\saved_models\cnn_filters_64_128.keras
# Training history saved to d:\Repositories\Convolutional-Neural-Network-and-Recurrent-Neural-Network\src\saved_models\cnn_filters_64_128_history.json
# Test Macro F1 Score: 0.7008290085221698
# [DONE] Training finished - macro F1 on test (Keras): 0.7008
# [START] Evaluating Keras model on test set...
# [DONE] Macro F1-score (Keras): 0.7008
# [START] Evaluating scratch CNN on test set...
# [DONE] Macro F1-score (scratch): 0.7008
# [START] Plotting training loss and accuracy history...
# [INFO] Using cached training history.
# [DONE] Plot displayed.
# [RESULT] Filters [64, 128] | Keras F1: 0.700829 | Scratch F1: 0.700829

# %%
histories_2 = {
    "16, 32 filters": cnn_filters_16_32.load_history(),
    "32, 64 filters": cnn_filters_32_64.load_history(),
    "64, 128 filters": cnn_filters_64_128.load_history(),
}

plot_multi_loss(histories_2)
# Out:
# [INFO] Using cached training history.
# [INFO] Using cached training history.
# [INFO] Using cached training history.

# %% [markdown]
# ## Hyperparameter: Size of Filters

# %% [markdown]
# ### 1. Kernel size 3x3

# %%
cnn_kernel_3x3 = CNNSuite(save_dir="saved_models", model_name="cnn_kernel_3x3.keras")
cnn_kernel_3x3.history_path = cnn_kernel_3x3.save_dir / "cnn_kernel_3x3_history.json"
cnn_kernel_3x3.load_data()
if cnn_kernel_3x3.model_path.exists() and cnn_kernel_3x3.history_path.exists():
    print("[INFO] Model and history already exist. Skipping training and loading history...")
    cnn_kernel_3x3.load_history()
else:
    cnn_kernel_3x3.train(epochs=10, batch_size=64, conv_layers=2, filters=[32, 64], kernel_size=[3, 3])
keras_cnn_kernel_3x3 = cnn_kernel_3x3.evaluate_keras()
scratch_cnn_kernel_3x3 = cnn_kernel_3x3.evaluate_scratch()
cnn_kernel_3x3.plot_history()
print(f"[RESULT] Kernel size = 3x3 | Keras F1 = {keras_cnn_kernel_3x3:.6f} | Scratch F1 = {scratch_cnn_kernel_3x3:.6f}\n")
# Out:
# [INIT] Initializing CNNSuite with model path 'saved_models/cnn_kernel_3x3.keras'
# [START] Loading dataset...
# [INFO] Downloading CIFAR-10 dataset...
# [INFO] Dataset downloaded successfully.
# [INFO] Normalizing image data...
# [INFO] Splitting training data: 50000 samples into 40000 train and 10000 validation samples.
# [INFO] Data loading and splitting complete.
# [DONE] Dataset loaded:
#   - train: (40000, 32, 32, 3), (40000,)
#   - val: (10000, 32, 32, 3), (10000,)
#   - test: (10000, 32, 32, 3), (10000,)
# [START] Training with [32, 64] filters, 10 epochs...
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 16s 23ms/step - accuracy: 0.3657 - loss: 1.7479 - val_accuracy: 0.5570 - val_loss: 1.2342
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 23ms/step - accuracy: 0.5946 - loss: 1.1496 - val_accuracy: 0.6293 - val_loss: 1.0354
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.6603 - loss: 0.9710 - val_accuracy: 0.6425 - val_loss: 1.0122
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 23ms/step - accuracy: 0.7005 - loss: 0.8611 - val_accuracy: 0.6822 - val_loss: 0.9102
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 24ms/step - accuracy: 0.7320 - loss: 0.7782 - val_accuracy: 0.6806 - val_loss: 0.9285
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.7531 - loss: 0.7153 - val_accuracy: 0.6925 - val_loss: 0.8911
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - accuracy: 0.7799 - loss: 0.6374 - val_accuracy: 0.6863 - val_loss: 0.9162
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.7979 - loss: 0.5831 - val_accuracy: 0.6954 - val_loss: 0.8929
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 15s 25ms/step - accuracy: 0.8217 - loss: 0.5155 - val_accuracy: 0.7096 - val_loss: 0.8793
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.8438 - loss: 0.4531 - val_accuracy: 0.6949 - val_loss: 0.9506
# Model saved to d:\Repositories\Convolutional-Neural-Network-and-Recurrent-Neural-Network\src\saved_models\cnn_kernel_3x3.keras
# Training history saved to d:\Repositories\Convolutional-Neural-Network-and-Recurrent-Neural-Network\src\saved_models\cnn_kernel_3x3_history.json
# Test Macro F1 Score: 0.6875389660232644
# [DONE] Training finished - macro F1 on test (Keras): 0.6875
# [START] Evaluating Keras model on test set...
# [DONE] Macro F1-score (Keras): 0.6875
# [START] Evaluating scratch CNN on test set...
# [DONE] Macro F1-score (scratch): 0.6875
# [START] Plotting training loss and accuracy history...
# [INFO] Using cached training history.
# [DONE] Plot displayed.
# [RESULT] Kernel size = 3x3 | Keras F1 = 0.687539 | Scratch F1 = 0.687539

# %% [markdown]
# ### 2. Kernel size 5x5

# %%
cnn_kernel_5x5 = CNNSuite(save_dir="saved_models", model_name="cnn_kernel_5x5.keras")
cnn_kernel_5x5.history_path = cnn_kernel_5x5.save_dir / "cnn_kernel_5x5_history.json"
cnn_kernel_5x5.load_data()
if cnn_kernel_5x5.model_path.exists() and cnn_kernel_5x5.history_path.exists():
    print("[INFO] Model and history already exist. Skipping training and loading history...")
    cnn_kernel_5x5.load_history()
else:
    cnn_kernel_5x5.train(epochs=10, batch_size=64, conv_layers=2, filters=[32, 64], kernel_size=[5, 5])
keras_cnn_kernel_5x5 = cnn_kernel_5x5.evaluate_keras()
scratch_cnn_kernel_5x5 = cnn_kernel_5x5.evaluate_scratch()
cnn_kernel_5x5.plot_history()
print(f"[RESULT] Kernel size = 5x5 | Keras F1 = {keras_cnn_kernel_5x5:.6f} | Scratch F1 = {scratch_cnn_kernel_5x5:.6f}\n")
# Out:
# [INIT] Initializing CNNSuite with model path 'saved_models/cnn_kernel_5x5.keras'
# [START] Loading dataset...
# [INFO] Downloading CIFAR-10 dataset...
# [INFO] Dataset downloaded successfully.
# [INFO] Normalizing image data...
# [INFO] Splitting training data: 50000 samples into 40000 train and 10000 validation samples.
# [INFO] Data loading and splitting complete.
# [DONE] Dataset loaded:
#   - train: (40000, 32, 32, 3), (40000,)
#   - val: (10000, 32, 32, 3), (10000,)
#   - test: (10000, 32, 32, 3), (10000,)
# [START] Training with [32, 64] filters, 10 epochs...
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 34ms/step - accuracy: 0.3630 - loss: 1.7487 - val_accuracy: 0.5458 - val_loss: 1.2675
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 36ms/step - accuracy: 0.5835 - loss: 1.1895 - val_accuracy: 0.6306 - val_loss: 1.0501
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.6528 - loss: 0.9905 - val_accuracy: 0.6688 - val_loss: 0.9400
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.6982 - loss: 0.8645 - val_accuracy: 0.6682 - val_loss: 0.9680
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.7363 - loss: 0.7553 - val_accuracy: 0.6909 - val_loss: 0.9029
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 36ms/step - accuracy: 0.7640 - loss: 0.6742 - val_accuracy: 0.6970 - val_loss: 0.8765
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.8012 - loss: 0.5774 - val_accuracy: 0.7059 - val_loss: 0.8805
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 36ms/step - accuracy: 0.8259 - loss: 0.4935 - val_accuracy: 0.6927 - val_loss: 0.9779
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 24s 38ms/step - accuracy: 0.8481 - loss: 0.4346 - val_accuracy: 0.6983 - val_loss: 0.9407
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.8772 - loss: 0.3600 - val_accuracy: 0.6961 - val_loss: 1.0198
# Model saved to d:\Repositories\Convolutional-Neural-Network-and-Recurrent-Neural-Network\src\saved_models\cnn_kernel_5x5.keras
# Training history saved to d:\Repositories\Convolutional-Neural-Network-and-Recurrent-Neural-Network\src\saved_models\cnn_kernel_5x5_history.json
# Test Macro F1 Score: 0.6878781328182344
# [DONE] Training finished - macro F1 on test (Keras): 0.6879
# [START] Evaluating Keras model on test set...
# [DONE] Macro F1-score (Keras): 0.6879
# [START] Evaluating scratch CNN on test set...
# [DONE] Macro F1-score (scratch): 0.6879
# [START] Plotting training loss and accuracy history...
# [INFO] Using cached training history.
# [DONE] Plot displayed.
# [RESULT] Kernel size = 5x5 | Keras F1 = 0.687878 | Scratch F1 = 0.687878

# %% [markdown]
# ### 3. Kernel size 7x7

# %%
cnn_kernel_7x7 = CNNSuite(save_dir="saved_models", model_name="cnn_kernel_7x7.keras")
cnn_kernel_7x7.history_path = cnn_kernel_7x7.save_dir / "cnn_kernel_7x7_history.json"
cnn_kernel_7x7.load_data()
if cnn_kernel_7x7.model_path.exists() and cnn_kernel_7x7.history_path.exists():
    print("[INFO] Model and history already exist. Skipping training and loading history...")
    cnn_kernel_7x7.load_history()
else:
    cnn_kernel_7x7.train(epochs=10, batch_size=64, conv_layers=2, filters=[32, 64], kernel_size=[7, 7])
keras_cnn_kernel_7x7 = cnn_kernel_7x7.evaluate_keras()
scratch_cnn_kernel_7x7 = cnn_kernel_7x7.evaluate_scratch()
cnn_kernel_7x7.plot_history()
print(f"[RESULT] Kernel size = 7x7 | Keras F1 = {keras_cnn_kernel_7x7:.6f} | Scratch F1 = {scratch_cnn_kernel_7x7:.6f}\n")
# Out:
# [INIT] Initializing CNNSuite with model path 'saved_models/cnn_kernel_7x7.keras'
# [START] Loading dataset...
# [INFO] Downloading CIFAR-10 dataset...
# [INFO] Dataset downloaded successfully.
# [INFO] Normalizing image data...
# [INFO] Splitting training data: 50000 samples into 40000 train and 10000 validation samples.
# [INFO] Data loading and splitting complete.
# [DONE] Dataset loaded:
#   - train: (40000, 32, 32, 3), (40000,)
#   - val: (10000, 32, 32, 3), (10000,)
#   - test: (10000, 32, 32, 3), (10000,)
# [START] Training with [32, 64] filters, 10 epochs...
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - accuracy: 0.3549 - loss: 1.7654 - val_accuracy: 0.5221 - val_loss: 1.3237
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 30s 48ms/step - accuracy: 0.5607 - loss: 1.2316 - val_accuracy: 0.6143 - val_loss: 1.0915
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 51ms/step - accuracy: 0.6288 - loss: 1.0487 - val_accuracy: 0.6381 - val_loss: 1.0335
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 52ms/step - accuracy: 0.6810 - loss: 0.9090 - val_accuracy: 0.6598 - val_loss: 0.9655
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 51ms/step - accuracy: 0.7178 - loss: 0.8009 - val_accuracy: 0.6571 - val_loss: 0.9907
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 51ms/step - accuracy: 0.7522 - loss: 0.7148 - val_accuracy: 0.6671 - val_loss: 0.9769
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.7844 - loss: 0.6081 - val_accuracy: 0.6762 - val_loss: 0.9888
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 51ms/step - accuracy: 0.8163 - loss: 0.5281 - val_accuracy: 0.6716 - val_loss: 1.0298
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 33s 54ms/step - accuracy: 0.8491 - loss: 0.4354 - val_accuracy: 0.6720 - val_loss: 1.0917
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 32s 51ms/step - accuracy: 0.8698 - loss: 0.3698 - val_accuracy: 0.6721 - val_loss: 1.1278
# Model saved to d:\Repositories\Convolutional-Neural-Network-and-Recurrent-Neural-Network\src\saved_models\cnn_kernel_7x7.keras
# Training history saved to d:\Repositories\Convolutional-Neural-Network-and-Recurrent-Neural-Network\src\saved_models\cnn_kernel_7x7_history.json
# Test Macro F1 Score: 0.6694376405225895
# [DONE] Training finished - macro F1 on test (Keras): 0.6694
# [START] Evaluating Keras model on test set...
# [DONE] Macro F1-score (Keras): 0.6694
# [START] Evaluating scratch CNN on test set...
# [DONE] Macro F1-score (scratch): 0.6694
# [START] Plotting training loss and accuracy history...
# [INFO] Using cached training history.
# [DONE] Plot displayed.
# [RESULT] Kernel size = 7x7 | Keras F1 = 0.669438 | Scratch F1 = 0.669438

# %%
histories_3 = {
    "3x3 kernel": cnn_kernel_3x3.load_history(),
    "5x5 kernel": cnn_kernel_5x5.load_history(),
    "7x7 kernel": cnn_kernel_7x7.load_history(),
}

plot_multi_loss(histories_3)
# Out:
# [INFO] Using cached training history.
# [INFO] Using cached training history.
# [INFO] Using cached training history.

# %% [markdown]
# ## Hyperparameter: Pooling Type (Max / Avg)

# %% [markdown]
# ### 1. Max Pooling

# %%
cnn_max = CNNSuite(save_dir="saved_models", model_name="cnn_pooling_max.keras")
cnn_max.history_path = cnn_max.save_dir / "cnn_pooling_max_history.json"
cnn_max.load_data()

if cnn_max.model_path.exists() and cnn_max.history_path.exists():
    print("[INFO] Pooling = max: Model and history already exist. Skipping training...")
    cnn_max.load_history()
else:
    cnn_max.train(epochs=10, batch_size=64, pooling="max")

keras_cnn_max = cnn_max.evaluate_keras()
scratch_cnn_max = cnn_max.evaluate_scratch()
cnn_max.plot_history()
print(f"[RESULT] Pooling = Max | Keras F1 = {keras_cnn_max:.6f} | Scratch F1 = {scratch_cnn_max:.6f}\n")
# Out:
# [INIT] Initializing CNNSuite with model path 'saved_models/cnn_pooling_max.keras'
# [START] Loading dataset...
# [INFO] Downloading CIFAR-10 dataset...
# [INFO] Dataset downloaded successfully.
# [INFO] Normalizing image data...
# [INFO] Splitting training data: 50000 samples into 40000 train and 10000 validation samples.
# [INFO] Data loading and splitting complete.
# [DONE] Dataset loaded:
#   - train: (40000, 32, 32, 3), (40000,)
#   - val: (10000, 32, 32, 3), (10000,)
#   - test: (10000, 32, 32, 3), (10000,)
# [INFO] Pooling = max: Model and history already exist. Skipping training...
# [INFO] Loading training history from saved_models\cnn_pooling_max_history.json...
# [INFO] Training history loaded.
# [START] Evaluating Keras model on test set...
# [DONE] Macro F1-score (Keras): 0.6824
# [START] Evaluating scratch CNN on test set...
# [DONE] Macro F1-score (scratch): 0.6824
# [START] Plotting training loss and accuracy history...
# [INFO] Using cached training history.
# [DONE] Plot displayed.
# [RESULT] Pooling = Max | Keras F1 = 0.682363 | Scratch F1 = 0.682363

# %% [markdown]
# ### 2. Average Pooling

# %%
cnn_avg = CNNSuite(save_dir="saved_models", model_name="cnn_pooling_avg.keras")
cnn_avg.history_path = cnn_avg.save_dir / "cnn_pooling_avg_history.json"
cnn_avg.load_data()

if cnn_avg.model_path.exists() and cnn_avg.history_path.exists():
    print("[INFO] Pooling = avg: Model and history already exist. Skipping training...")
    cnn_avg.load_history()
else:
    cnn_avg.train(epochs=10, batch_size=64, pooling="avg", pool_size=2)

keras_cnn_avg = cnn_avg.evaluate_keras()
scratch_cnn_avg = cnn_avg.evaluate_scratch()
cnn_avg.plot_history()
print(f"[RESULT] Pooling = Average | Keras F1 = {keras_cnn_avg:.6f} | Scratch F1 = {scratch_cnn_avg:.6f}\n")
# Out:
# [INIT] Initializing CNNSuite with model path 'saved_models/cnn_pooling_avg.keras'
# [START] Loading dataset...
# [INFO] Downloading CIFAR-10 dataset...
# [INFO] Dataset downloaded successfully.
# [INFO] Normalizing image data...
# [INFO] Splitting training data: 50000 samples into 40000 train and 10000 validation samples.
# [INFO] Data loading and splitting complete.
# [DONE] Dataset loaded:
#   - train: (40000, 32, 32, 3), (40000,)
#   - val: (10000, 32, 32, 3), (10000,)
#   - test: (10000, 32, 32, 3), (10000,)
# [START] Training with 32 filters, 10 epochs...
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.3364 - loss: 1.8205 - val_accuracy: 0.5109 - val_loss: 1.3604
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.5333 - loss: 1.3219 - val_accuracy: 0.5714 - val_loss: 1.2072
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 14ms/step - accuracy: 0.5818 - loss: 1.1829 - val_accuracy: 0.5947 - val_loss: 1.1367
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.6174 - loss: 1.0921 - val_accuracy: 0.6095 - val_loss: 1.0948
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.6440 - loss: 1.0130 - val_accuracy: 0.6294 - val_loss: 1.0322
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.6691 - loss: 0.9443 - val_accuracy: 0.6393 - val_loss: 1.0063
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 14ms/step - accuracy: 0.6986 - loss: 0.8658 - val_accuracy: 0.6544 - val_loss: 0.9732
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7136 - loss: 0.8236 - val_accuracy: 0.6699 - val_loss: 0.9398
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7306 - loss: 0.7756 - val_accuracy: 0.6688 - val_loss: 0.9645
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7410 - loss: 0.7281 - val_accuracy: 0.6797 - val_loss: 0.9169
# Model saved to d:\Repositories\Convolutional-Neural-Network-and-Recurrent-Neural-Network\src\saved_models\cnn_pooling_avg.keras
# Training history saved to d:\Repositories\Convolutional-Neural-Network-and-Recurrent-Neural-Network\src\saved_models\cnn_pooling_avg_history.json
# Test Macro F1 Score: 0.6750267297909724
# [DONE] Training finished - macro F1 on test (Keras): 0.6750
# [START] Evaluating Keras model on test set...
# [DONE] Macro F1-score (Keras): 0.6750
# [START] Evaluating scratch CNN on test set...
# [DONE] Macro F1-score (scratch): 0.6750
# [START] Plotting training loss and accuracy history...
# [INFO] Using cached training history.
# [DONE] Plot displayed.
# [RESULT] Pooling = Average | Keras F1 = 0.675027 | Scratch F1 = 0.675027

# %%
histories_pool = {
    "max pooling": cnn_max.load_history(),
    "avg pooling": cnn_avg.load_history(),
}

plot_multi_loss(histories_pool)
# Out:
# [INFO] Using cached training history.
# [INFO] Using cached training history.
